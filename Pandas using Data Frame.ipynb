# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
store=pd.read_csv(r"D:\FSDS\20th(mar25)-pandas\20th, 21st\DataFrame_ Pandas\Sample - Superstore_Orders.csv")

# %%
store
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
id(store) # it displays the address
# Out:
# 2258789508640

# %%
len(store) # it gives only rows
# Out:
# 10194

# %%
store.columns # it displays the all column names in dataset.
# Out:
# Index(['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
#        'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category',
#        'Discount', 'Profit', 'Quantity', 'Sales'],
#       dtype='object')

# %%
len(store.columns)
# Out:
# 19

# %%
store.isnull()
# Out:
#        Category   City  Country/Region  Customer Name  Manufacturer  \
# 0         False  False           False          False         False
# 1         False  False           False          False         False
# 2         False  False           False          False         False
# 3         False  False           False          False         False
# 4         False  False           False          False         False
# ...         ...    ...             ...            ...           ...
# 10189     False  False           False          False         False
# 10190     False  False           False          False         False
# 10191     False  False           False          False         False
# 10192     False  False           False          False         False
# 10193     False  False           False          False         False
#
#        Order Date  Order ID  Postal Code  Product Name  Region  Segment  \
# 0           False     False        False         False   False    False
# ...

# %%
store.isnull().sum()
# Out:
# Category          0
# City              0
# Country/Region    0
# Customer Name     0
# Manufacturer      0
# Order Date        0
# Order ID          0
# Postal Code       0
# Product Name      0
# Region            0
# Segment           0
# Ship Date         0
# Ship Mode         0
# State/Province    0
# Sub-Category      0
# Discount          0
# Profit            0
# Quantity          0
# Sales             0
# dtype: int64

# %%
store.shape   # it displays the rows & columns
# Out:
# (10194, 19)

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        10194 non-null  object
#  1   City            10194 non-null  object
#  2   Country/Region  10194 non-null  object
#  3   Customer Name   10194 non-null  object
#  4   Manufacturer    10194 non-null  object
#  5   Order Date      10194 non-null  object
#  6   Order ID        10194 non-null  object
#  7   Postal Code     10194 non-null  object
#  8   Product Name    10194 non-null  object
#  9   Region          10194 non-null  object
#  10  Segment         10194 non-null  object
#  11  Ship Date       10194 non-null  object
#  12  Ship Mode       10194 non-null  object
#  13  State/Province  10194 non-null  object
#  14  Sub-Category    10194 non-null  object
#  15  Discount        10194 non-null  float64
#  16  Profit          10194 non-null  float64
# ...

# %%
store[:]
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store[0:10]
# Out:
#           Category          City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies       Houston  United States  Darren Powers  Message Book
# 1  Office Supplies    Naperville  United States  Phillina Ober           GBC
# 2  Office Supplies    Naperville  United States  Phillina Ober         Avery
# 3  Office Supplies    Naperville  United States  Phillina Ober         SAFCO
# 4  Office Supplies  Philadelphia  United States     Mick Brown         Avery
# 5        Furniture     Henderson  United States  Maria Etezadi        Global
# 6  Office Supplies     Henderson  United States  Maria Etezadi        Rogers
# 7  Office Supplies        Athens  United States  Jack O'Briant         Dixon
# 8  Office Supplies     Henderson  United States  Maria Etezadi         Ibico
# 9  Office Supplies     Henderson  United States  Maria Etezadi      Alliance
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77015
# ...

# %%
store[0:20:5]
# Out:
#            Category        City Country/Region     Customer Name  \
# 0   Office Supplies     Houston  United States     Darren Powers
# 5         Furniture   Henderson  United States     Maria Etezadi
# 10  Office Supplies   Henderson  United States     Maria Etezadi
# 15  Office Supplies  Huntsville  United States  Vivek Sundaresam
#
#     Manufacturer  Order Date        Order ID Postal Code  \
# 0   Message Book  03-01-2020  US-2020-103800       77015
# 5         Global  06-01-2020  US-2020-167199       42420
# 10    Southworth  06-01-2020  US-2020-167199       42420
# 15          Acco  07-01-2020  US-2020-105417       77340
#
#                                          Product Name   Region      Segment  \
# 0   Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central     Consumer
# 5             Global Deluxe High-Back Manager's Chair    South  Home Office
# 10    Southworth 25% Cotton Granite Paper & Envelopes    South  Home Office
# ...

# %%
store.head() # it displays the top 5 rows
# Out:
#           Category          City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies       Houston  United States  Darren Powers  Message Book
# 1  Office Supplies    Naperville  United States  Phillina Ober           GBC
# 2  Office Supplies    Naperville  United States  Phillina Ober         Avery
# 3  Office Supplies    Naperville  United States  Phillina Ober         SAFCO
# 4  Office Supplies  Philadelphia  United States     Mick Brown         Avery
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77015
# 1  04-01-2020  US-2020-112326       60540
# 2  04-01-2020  US-2020-112326       60540
# 3  04-01-2020  US-2020-112326       60540
# 4  05-01-2020  US-2020-141817       19143
#
#                                         Product Name   Region      Segment  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central     Consumer
# 1         GBC Standard Plastic Binding Systems Combs  Central  Home Office
# ...

# %%
store.head(3)
# Out:
#           Category        City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies     Houston  United States  Darren Powers  Message Book
# 1  Office Supplies  Naperville  United States  Phillina Ober           GBC
# 2  Office Supplies  Naperville  United States  Phillina Ober         Avery
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77015
# 1  04-01-2020  US-2020-112326       60540
# 2  04-01-2020  US-2020-112326       60540
#
#                                         Product Name   Region      Segment  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central     Consumer
# 1         GBC Standard Plastic Binding Systems Combs  Central  Home Office
# 2                                          Avery 508  Central  Home Office
#
#     Ship Date       Ship Mode State/Province Sub-Category  Discount  Profit  \
# 0  07-01-2020  Standard Class          Texas        Paper       0.2  5.5512
# ...

# %%
store.tail() # it displays the bottom rows of dataset.
# Out:
#               Category           City Country/Region      Customer Name  \
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# 10189  Wilson Jones  30-12-2023  US-2023-143259       10009
# 10190           GBC  30-12-2023  US-2023-115427       94533
# 10191         Other  30-12-2023  US-2023-156720       80538
# 10192         Other  30-12-2023  US-2023-143259       10009
# 10193  Wilson Jones  30-12-2023  CA-2023-143500         C0A
#
#                                Product Name Region    Segment   Ship Date  \
# 10189  Wilson Jones Legal Size Ring Binders   East   Consumer  03-01-2024
# ...

# %%
store.tail(3)
# Out:
#               Category           City Country/Region      Customer Name  \
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# 10191         Other  30-12-2023  US-2023-156720       80538
# 10192         Other  30-12-2023  US-2023-143259       10009
# 10193  Wilson Jones  30-12-2023  CA-2023-143500         C0A
#
#                       Product Name Region   Segment   Ship Date  \
# 10191          Bagged Rubber Bands   West  Consumer  03-01-2024
# 10192    Gear Head AU3700S Headset   East  Consumer  03-01-2024
# 10193  Wilson Jones Impact Binders   East  Consumer  03-01-2024
#
#             Ship Mode        State/Province Sub-Category  Discount  Profit  \
# 10191  Standard Class              Colorado    Fasteners       0.2 -0.6048
# ...

# %%
store.isna() #isna() & isnull() both are same.
# Out:
#        Category   City  Country/Region  Customer Name  Manufacturer  \
# 0         False  False           False          False         False
# 1         False  False           False          False         False
# 2         False  False           False          False         False
# 3         False  False           False          False         False
# 4         False  False           False          False         False
# ...         ...    ...             ...            ...           ...
# 10189     False  False           False          False         False
# 10190     False  False           False          False         False
# 10191     False  False           False          False         False
# 10192     False  False           False          False         False
# 10193     False  False           False          False         False
#
#        Order Date  Order ID  Postal Code  Product Name  Region  Segment  \
# 0           False     False        False         False   False    False
# ...

# %% [markdown]
# # statistical concepts in pandas

# %%
store.describe() # it displays the number(numerical data columns)
# Out:
#            Discount        Profit      Quantity         Sales
# count  10194.000000  10194.000000  10194.000000  10194.000000
# mean       0.155385     28.673417      3.791838    228.225854
# std        0.206249    232.465115      2.228317    619.906839
# min        0.000000  -6599.978000      1.000000      0.444000
# 25%        0.000000      1.760800      2.000000     17.220000
# 50%        0.200000      8.690000      3.000000     53.910000
# 75%        0.200000     29.297925      5.000000    209.500000
# max        0.800000   8399.976000     14.000000  22638.480000

# %%
store.columns
# Out:
# Index(['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
#        'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category',
#        'Discount', 'Profit', 'Quantity', 'Sales'],
#       dtype='object')

# %%
store['Category']
# Out:
# 0        Office Supplies
# 1        Office Supplies
# 2        Office Supplies
# 3        Office Supplies
# 4        Office Supplies
#               ...
# 10189    Office Supplies
# 10190    Office Supplies
# 10191    Office Supplies
# 10192         Technology
# 10193    Office Supplies
# Name: Category, Length: 10194, dtype: object

# %%
store[['Category','City']] # two square brackets we should add
# Out:
#               Category           City
# 0      Office Supplies        Houston
# 1      Office Supplies     Naperville
# 2      Office Supplies     Naperville
# 3      Office Supplies     Naperville
# 4      Office Supplies   Philadelphia
# ...                ...            ...
# 10189  Office Supplies  New York City
# 10190  Office Supplies      Fairfield
# 10191  Office Supplies       Loveland
# 10192       Technology  New York City
# 10193  Office Supplies  Charlottetown
#
# [10194 rows x 2 columns]

# %%
store[['Category','City','Customer Name']] # two square brackets we should add
# Out:
#               Category           City      Customer Name
# 0      Office Supplies        Houston      Darren Powers
# 1      Office Supplies     Naperville      Phillina Ober
# 2      Office Supplies     Naperville      Phillina Ober
# 3      Office Supplies     Naperville      Phillina Ober
# 4      Office Supplies   Philadelphia         Mick Brown
# ...                ...            ...                ...
# 10189  Office Supplies  New York City  Patrick O'Donnell
# 10190  Office Supplies      Fairfield         Erica Bern
# 10191  Office Supplies       Loveland      Jill Matthias
# 10192       Technology  New York City  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown        Harry Olson
#
# [10194 rows x 3 columns]

# %%
store.columns
# Out:
# Index(['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
#        'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category',
#        'Discount', 'Profit', 'Quantity', 'Sales'],
#       dtype='object')

# %%
Store_cat=store[['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
       'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
       'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category']]
Store_cat
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
Store_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        10194 non-null  object
#  1   City            10194 non-null  object
#  2   Country/Region  10194 non-null  object
#  3   Customer Name   10194 non-null  object
#  4   Manufacturer    10194 non-null  object
#  5   Order Date      10194 non-null  object
#  6   Order ID        10194 non-null  object
#  7   Postal Code     10194 non-null  object
#  8   Product Name    10194 non-null  object
#  9   Region          10194 non-null  object
#  10  Segment         10194 non-null  object
#  11  Ship Date       10194 non-null  object
#  12  Ship Mode       10194 non-null  object
#  13  State/Province  10194 non-null  object
#  14  Sub-Category    10194 non-null  object
# dtypes: object(15)
# memory usage: 1.2+ MB

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        10194 non-null  object
#  1   City            10194 non-null  object
#  2   Country/Region  10194 non-null  object
#  3   Customer Name   10194 non-null  object
#  4   Manufacturer    10194 non-null  object
#  5   Order Date      10194 non-null  object
#  6   Order ID        10194 non-null  object
#  7   Postal Code     10194 non-null  object
#  8   Product Name    10194 non-null  object
#  9   Region          10194 non-null  object
#  10  Segment         10194 non-null  object
#  11  Ship Date       10194 non-null  object
#  12  Ship Mode       10194 non-null  object
#  13  State/Province  10194 non-null  object
#  14  Sub-Category    10194 non-null  object
#  15  Discount        10194 non-null  float64
#  16  Profit          10194 non-null  float64
# ...

# %%
len(Store_cat.columns)
# Out:
# 15

# %%
len(store.columns)
# Out:
# 19

# %%
store.columns
# Out:
# Index(['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
#        'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category',
#        'Discount', 'Profit', 'Quantity', 'Sales'],
#       dtype='object')

# %%
Store_num=store[['Discount', 'Profit', 'Quantity', 'Sales']]
Store_num
# Out:
#        Discount   Profit  Quantity    Sales
# 0           0.2   5.5512         2   16.448
# 1           0.8  -5.4870         2    3.540
# 2           0.2   4.2717         3   11.784
# 3           0.2 -64.7748         3  272.736
# 4           0.2   4.8840         3   19.536
# ...         ...      ...       ...      ...
# 10189       0.2  19.7910         3   52.776
# 10190       0.2   6.4750         2   20.720
# 10191       0.2  -0.6048         3    3.024
# 10192       0.0   2.7279         7   90.930
# 10193       0.2  -0.6048         3    3.024
#
# [10194 rows x 4 columns]

# %%
Store_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Discount  10194 non-null  float64
#  1   Profit    10194 non-null  float64
#  2   Quantity  10194 non-null  int64
#  3   Sales     10194 non-null  float64
# dtypes: float64(3), int64(1)
# memory usage: 318.7 KB

# %%
print(len(store.columns))
print(len(Store_cat.columns))
print(len(Store_num.columns))
# Out:
# 19
# 15
# 4

# %%
Store_cat.describe()
# Out:
#                Category           City Country/Region  Customer Name  \
# count             10194          10194          10194          10194
# unique                3            542              2            800
# top     Office Supplies  New York City  United States  William Brown
# freq               6128            915           9994             41
#
#        Manufacturer  Order Date        Order ID Postal Code Product Name  \
# count         10194       10194           10194       10194        10194
# unique          183        1242            5111         655         1849
# top           Other  05-09-2022  US-2023-100111       10035      Staples
# freq           1940          38              14         263           50
#
#        Region   Segment   Ship Date       Ship Mode State/Province  \
# count   10194     10194       10194           10194          10194
# unique      4         3        1338               4             59
# ...

# %%
Store_num.describe()
# Out:
#            Discount        Profit      Quantity         Sales
# count  10194.000000  10194.000000  10194.000000  10194.000000
# mean       0.155385     28.673417      3.791838    228.225854
# std        0.206249    232.465115      2.228317    619.906839
# min        0.000000  -6599.978000      1.000000      0.444000
# 25%        0.000000      1.760800      2.000000     17.220000
# 50%        0.200000      8.690000      3.000000     53.910000
# 75%        0.200000     29.297925      5.000000    209.500000
# max        0.800000   8399.976000     14.000000  22638.480000

# %%
store.describe().transpose()
# Out:
#             count        mean         std       min      25%    50%  \
# Discount  10194.0    0.155385    0.206249     0.000   0.0000   0.20
# Profit    10194.0   28.673417  232.465115 -6599.978   1.7608   8.69
# Quantity  10194.0    3.791838    2.228317     1.000   2.0000   3.00
# Sales     10194.0  228.225854  619.906839     0.444  17.2200  53.91
#
#                  75%        max
# Discount    0.200000      0.800
# Profit     29.297925   8399.976
# Quantity    5.000000     14.000
# Sales     209.500000  22638.480

# %%
store.describe().T # Both are same
# Out:
#             count        mean         std       min      25%    50%  \
# Discount  10194.0    0.155385    0.206249     0.000   0.0000   0.20
# Profit    10194.0   28.673417  232.465115 -6599.978   1.7608   8.69
# Quantity  10194.0    3.791838    2.228317     1.000   2.0000   3.00
# Sales     10194.0  228.225854  619.906839     0.444  17.2200  53.91
#
#                  75%        max
# Discount    0.200000      0.800
# Profit     29.297925   8399.976
# Quantity    5.000000     14.000
# Sales     209.500000  22638.480

# %%
store.columns
# Out:
# Index(['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
#        'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category',
#        'Discount', 'Profit', 'Quantity', 'Sales'],
#       dtype='object')

# %%
len(store.columns)
# Out:
# 19

# %%
store.dtypes
# Out:
# Category           object
# City               object
# Country/Region     object
# Customer Name      object
# Manufacturer       object
# Order Date         object
# Order ID           object
# Postal Code        object
# Product Name       object
# Region             object
# Segment            object
# Ship Date          object
# Ship Mode          object
# State/Province     object
# Sub-Category       object
# Discount          float64
# Profit            float64
# Quantity            int64
# Sales             float64
# dtype: object

# %%
store[['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
       'Order Date', 'Order ID', 'Postal Code']]
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code
# ...

# %%
Store_cat.columns
# Out:
# Index(['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
#        'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category'],
#       dtype='object')

# %%
Store_cat[['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer']]
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer
# 0      Message Book
# 1               GBC
# 2             Avery
# ...

# %%
store[:]
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store[1:10]
# Out:
#           Category          City Country/Region  Customer Name Manufacturer  \
# 1  Office Supplies    Naperville  United States  Phillina Ober          GBC
# 2  Office Supplies    Naperville  United States  Phillina Ober        Avery
# 3  Office Supplies    Naperville  United States  Phillina Ober        SAFCO
# 4  Office Supplies  Philadelphia  United States     Mick Brown        Avery
# 5        Furniture     Henderson  United States  Maria Etezadi       Global
# 6  Office Supplies     Henderson  United States  Maria Etezadi       Rogers
# 7  Office Supplies        Athens  United States  Jack O'Briant        Dixon
# 8  Office Supplies     Henderson  United States  Maria Etezadi        Ibico
# 9  Office Supplies     Henderson  United States  Maria Etezadi     Alliance
#
#    Order Date        Order ID Postal Code  \
# 1  04-01-2020  US-2020-112326       60540
# 2  04-01-2020  US-2020-112326       60540
# 3  04-01-2020  US-2020-112326       60540
# ...

# %%
store[0:50:10]
# Out:
#            Category           City Country/Region  Customer Name  \
# 0   Office Supplies        Houston  United States  Darren Powers
# 10  Office Supplies      Henderson  United States  Maria Etezadi
# 20        Furniture          Dover  United States    Seth Vernon
# 30  Office Supplies  San Francisco  United States   Brian Dahlen
# 40  Office Supplies     Scottsdale  United States  Toby Swindell
#
#     Manufacturer  Order Date        Order ID Postal Code  \
# 0   Message Book  03-01-2020  US-2020-103800       77015
# 10    Southworth  06-01-2020  US-2020-167199       42420
# 20           DAX  11-01-2020  US-2020-130092       19901
# 30       Tennsco  13-01-2020  US-2020-157147       94109
# 40           GBC  19-01-2020  US-2020-146591       85254
#
#                                          Product Name   Region      Segment  \
# 0   Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central     Consumer
# ...

# %%
store[::-1]
# Out:
#               Category           City Country/Region      Customer Name  \
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# ...                ...            ...            ...                ...
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 0      Office Supplies        Houston  United States      Darren Powers
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store[::20]
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 20           Furniture          Dover  United States        Seth Vernon
# 40     Office Supplies     Scottsdale  United States      Toby Swindell
# 60           Furniture          Miami  United States   Tom Boeckenhauer
# 80     Office Supplies  New York City  United States    Jasper Cacioppo
# ...                ...            ...            ...                ...
# 10100  Office Supplies    Little Rock  United States     Monica Federle
# 10120  Office Supplies        Seattle  United States         Alan Hwang
# 10140  Office Supplies    Los Angeles  United States       Fred Hopkins
# 10160  Office Supplies  New York City  United States  Jennifer Ferguson
# 10180  Office Supplies  New York City  United States       Michael Chen
#
#              Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store[::-1].head()
# Out:
#               Category           City Country/Region      Customer Name  \
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# 10193  Wilson Jones  30-12-2023  CA-2023-143500         C0A
# 10192         Other  30-12-2023  US-2023-143259       10009
# 10191         Other  30-12-2023  US-2023-156720       80538
# 10190           GBC  30-12-2023  US-2023-115427       94533
# 10189  Wilson Jones  30-12-2023  US-2023-143259       10009
#
#                                Product Name Region    Segment   Ship Date  \
# 10193           Wilson Jones Impact Binders   East   Consumer  03-01-2024
# ...

# %%
store[::-1].tail()
# Out:
#           Category          City Country/Region  Customer Name  Manufacturer  \
# 4  Office Supplies  Philadelphia  United States     Mick Brown         Avery
# 3  Office Supplies    Naperville  United States  Phillina Ober         SAFCO
# 2  Office Supplies    Naperville  United States  Phillina Ober         Avery
# 1  Office Supplies    Naperville  United States  Phillina Ober           GBC
# 0  Office Supplies       Houston  United States  Darren Powers  Message Book
#
#    Order Date        Order ID Postal Code  \
# 4  05-01-2020  US-2020-141817       19143
# 3  04-01-2020  US-2020-112326       60540
# 2  04-01-2020  US-2020-112326       60540
# 1  04-01-2020  US-2020-112326       60540
# 0  03-01-2020  US-2020-103800       77015
#
#                                         Product Name   Region      Segment  \
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ...     East     Consumer
# 3                      SAFCO Boltless Steel Shelving  Central  Home Office
# ...

# %%
store[::2]
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# 6      Office Supplies      Henderson  United States      Maria Etezadi
# 8      Office Supplies      Henderson  United States      Maria Etezadi
# ...                ...            ...            ...                ...
# 10184        Furniture    Quebec City         Canada       Bruce Galang
# 10186        Furniture  New York City  United States  Patrick O'Donnell
# 10188  Office Supplies      Fairfield  United States         Erica Bern
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10192       Technology  New York City  United States  Patrick O'Donnell
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store[::20]
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 20           Furniture          Dover  United States        Seth Vernon
# 40     Office Supplies     Scottsdale  United States      Toby Swindell
# 60           Furniture          Miami  United States   Tom Boeckenhauer
# 80     Office Supplies  New York City  United States    Jasper Cacioppo
# ...                ...            ...            ...                ...
# 10100  Office Supplies    Little Rock  United States     Monica Federle
# 10120  Office Supplies        Seattle  United States         Alan Hwang
# 10140  Office Supplies    Los Angeles  United States       Fred Hopkins
# 10160  Office Supplies  New York City  United States  Jennifer Ferguson
# 10180  Office Supplies  New York City  United States       Michael Chen
#
#              Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store[::-20]
# Out:
#               Category           City Country/Region       Customer Name  \
# 10193  Office Supplies  Charlottetown         Canada         Harry Olson
# 10173        Furniture    Los Angeles  United States        James Galang
# 10153        Furniture     Long Beach  United States         Jason Gross
# 10133  Office Supplies        Everett  United States    Giulietta Dortch
# 10113  Office Supplies    New Bedford  United States       Nick Crebassa
# ...                ...            ...            ...                 ...
# 93     Office Supplies     Romeoville  United States   Delfina Latchford
# 73     Office Supplies     Alexandria  United States     Shirley Daniels
# 53     Office Supplies         Smyrna  United States  Muhammed MacIntyre
# 33          Technology        Roswell  United States       Erica Hackney
# 13          Technology      Henderson  United States       Maria Etezadi
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store[21:26]
# Out:
#            Category            City Country/Region      Customer Name  \
# 21        Furniture   San Francisco  United States       Brian Dahlen
# 22        Furniture  Mount Pleasant  United States  Natalie DeCherney
# 23  Office Supplies   San Francisco  United States       Brian Dahlen
# 24  Office Supplies          Newark  United States      Michael Moore
# 25  Office Supplies    Bossier City  United States    Chris Selesnick
#
#           Manufacturer  Order Date        Order ID Postal Code  \
# 21          O'Sullivan  13-01-2020  US-2020-157147       94109
# 22              Global  13-01-2020  US-2020-109232       29464
# 23               Other  13-01-2020  US-2020-157147       94109
# 24               Avery  13-01-2020  US-2020-118192       43055
# 25  3-ring staple pack  13-01-2020  US-2020-162775       71111
#
#                                      Product Name Region    Segment  \
# 21  O'Sullivan Elevations Bookcase, Cherry Finish   West   Consumer
# ...

# %%
store['Customer Name'].head()
# Out:
# 0    Darren Powers
# 1    Phillina Ober
# 2    Phillina Ober
# 3    Phillina Ober
# 4       Mick Brown
# Name: Customer Name, dtype: object

# %%
store[['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
 'Product Name', 'Region']].head()
# Out:
#           Category          City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies       Houston  United States  Darren Powers  Message Book
# 1  Office Supplies    Naperville  United States  Phillina Ober           GBC
# 2  Office Supplies    Naperville  United States  Phillina Ober         Avery
# 3  Office Supplies    Naperville  United States  Phillina Ober         SAFCO
# 4  Office Supplies  Philadelphia  United States     Mick Brown         Avery
#
#                                         Product Name   Region
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central
# 1         GBC Standard Plastic Binding Systems Combs  Central
# 2                                          Avery 508  Central
# 3                      SAFCO Boltless Steel Shelving  Central
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ...     East

# %%
store[4:8][['Category', 'City', 'Country/Region']]
# Out:
#           Category          City Country/Region
# 4  Office Supplies  Philadelphia  United States
# 5        Furniture     Henderson  United States
# 6  Office Supplies     Henderson  United States
# 7  Office Supplies        Athens  United States

# %%
store[['Category', 'City', 'Country/Region']][4:7]
# Out:
#           Category          City Country/Region
# 4  Office Supplies  Philadelphia  United States
# 5        Furniture     Henderson  United States
# 6  Office Supplies     Henderson  United States

# %%
store[2:30:5][['Category', 'City', 'Country/Region']]
# Out:
#            Category            City Country/Region
# 2   Office Supplies      Naperville  United States
# 7   Office Supplies          Athens  United States
# 12       Technology       Henderson  United States
# 17       Technology          Laredo  United States
# 22        Furniture  Mount Pleasant  United States
# 27  Office Supplies    Bossier City  United States

# %%
store.columns
# Out:
# Index(['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
#        'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category',
#        'Discount', 'Profit', 'Quantity', 'Sales'],
#       dtype='object')

# %%
store1=store[['City','Customer Name','Product Name']][5:18]
store1
# Out:
#            City     Customer Name  \
# 5     Henderson     Maria Etezadi
# 6     Henderson     Maria Etezadi
# 7        Athens     Jack O'Briant
# 8     Henderson     Maria Etezadi
# 9     Henderson     Maria Etezadi
# 10    Henderson     Maria Etezadi
# 11  Los Angeles  Lycoris Saunders
# 12    Henderson     Maria Etezadi
# 13    Henderson     Maria Etezadi
# 14   Huntsville  Vivek Sundaresam
# 15   Huntsville  Vivek Sundaresam
# 16       Laredo     Melanie Seite
# 17       Laredo     Melanie Seite
#
#                                          Product Name
# 5             Global Deluxe High-Back Manager's Chair
# 6             Rogers Handheld Barrel Pencil Sharpener
# 7   Dixon Prang Watercolor Pencils, 10-Color Set w...
# 8                 Ibico Hi-Tech Manual Binding System
# 9           Alliance Super-Size Bands, Assorted Sizes
# 10    Southworth 25% Cotton Granite Paper & Envelopes
# 11                                          Xerox 225
# ...

# %%
store2=store[6:30:5]
store2
# Out:
#            Category           City Country/Region     Customer Name  \
# 6   Office Supplies      Henderson  United States     Maria Etezadi
# 11  Office Supplies    Los Angeles  United States  Lycoris Saunders
# 16  Office Supplies         Laredo  United States     Melanie Seite
# 21        Furniture  San Francisco  United States      Brian Dahlen
# 26  Office Supplies   Bossier City  United States   Chris Selesnick
#
#    Manufacturer  Order Date        Order ID Postal Code  \
# 6        Rogers  06-01-2020  US-2020-167199       42420
# 11        Xerox  06-01-2020  US-2020-130813       90049
# 16       Newell  09-01-2020  US-2020-135405       78041
# 21   O'Sullivan  13-01-2020  US-2020-157147       94109
# 26        Other  13-01-2020  US-2020-162775       71111
#
#                                      Product Name   Region      Segment  \
# 6         Rogers Handheld Barrel Pencil Sharpener    South  Home Office
# ...

# %%
Store_num
# Out:
#        Discount   Profit  Quantity    Sales
# 0           0.2   5.5512         2   16.448
# 1           0.8  -5.4870         2    3.540
# 2           0.2   4.2717         3   11.784
# 3           0.2 -64.7748         3  272.736
# 4           0.2   4.8840         3   19.536
# ...         ...      ...       ...      ...
# 10189       0.2  19.7910         3   52.776
# 10190       0.2   6.4750         2   20.720
# 10191       0.2  -0.6048         3    3.024
# 10192       0.0   2.7279         7   90.930
# 10193       0.2  -0.6048         3    3.024
#
# [10194 rows x 4 columns]

# %%
Store_num.Profit * Store_num.Sales
# Out:
# 0           91.306138
# 1          -19.423980
# 2           50.337713
# 3       -17666.419853
# 4           95.413824
#              ...
# 10189     1044.489816
# 10190      134.162000
# 10191       -1.828915
# 10192      248.047947
# 10193       -1.828915
# Length: 10194, dtype: float64

# %%
Store_num['myCalc'] = Store_num.Profit * Store_num.Sales
# Out:
# C:\Users\Sai Vamshi\AppData\Local\Temp\ipykernel_20288\1094312369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Store_num['myCalc'] = Store_num.Profit * Store_num.Sales

# %%
Store_num['myCalc']
# Out:
# 0           91.306138
# 1          -19.423980
# 2           50.337713
# 3       -17666.419853
# 4           95.413824
#              ...
# 10189     1044.489816
# 10190      134.162000
# 10191       -1.828915
# 10192      248.047947
# 10193       -1.828915
# Name: myCalc, Length: 10194, dtype: float64

# %%
Store_num
# Out:
#        Discount   Profit  Quantity    Sales        myCalc
# 0           0.2   5.5512         2   16.448     91.306138
# 1           0.8  -5.4870         2    3.540    -19.423980
# 2           0.2   4.2717         3   11.784     50.337713
# 3           0.2 -64.7748         3  272.736 -17666.419853
# 4           0.2   4.8840         3   19.536     95.413824
# ...         ...      ...       ...      ...           ...
# 10189       0.2  19.7910         3   52.776   1044.489816
# 10190       0.2   6.4750         2   20.720    134.162000
# 10191       0.2  -0.6048         3    3.024     -1.828915
# 10192       0.0   2.7279         7   90.930    248.047947
# 10193       0.2  -0.6048         3    3.024     -1.828915
#
# [10194 rows x 5 columns]

# %%
Store_num.head()
# Out:
#    Discount   Profit  Quantity    Sales        myCalc
# 0       0.2   5.5512         2   16.448     91.306138
# 1       0.8  -5.4870         2    3.540    -19.423980
# 2       0.2   4.2717         3   11.784     50.337713
# 3       0.2 -64.7748         3  272.736 -17666.419853
# 4       0.2   4.8840         3   19.536     95.413824

# %%
Store_num.drop('myClac', axis=1)
# Out:
#        Discount   Profit  Quantity    Sales        myCalc
# 0           0.2   5.5512         2   16.448     91.306138
# 1           0.8  -5.4870         2    3.540    -19.423980
# 2           0.2   4.2717         3   11.784     50.337713
# 3           0.2 -64.7748         3  272.736 -17666.419853
# 4           0.2   4.8840         3   19.536     95.413824
# ...         ...      ...       ...      ...           ...
# 10189       0.2  19.7910         3   52.776   1044.489816
# 10190       0.2   6.4750         2   20.720    134.162000
# 10191       0.2  -0.6048         3    3.024     -1.828915
# 10192       0.0   2.7279         7   90.930    248.047947
# 10193       0.2  -0.6048         3    3.024     -1.828915
#
# [10194 rows x 5 columns]

# %%
Store_num=Store_num.drop('myCalc', axis=1)

# %%
Store_num
# Out:
#        Discount   Profit  Quantity    Sales
# 0           0.2   5.5512         2   16.448
# 1           0.8  -5.4870         2    3.540
# 2           0.2   4.2717         3   11.784
# 3           0.2 -64.7748         3  272.736
# 4           0.2   4.8840         3   19.536
# ...         ...      ...       ...      ...
# 10189       0.2  19.7910         3   52.776
# 10190       0.2   6.4750         2   20.720
# 10191       0.2  -0.6048         3    3.024
# 10192       0.0   2.7279         7   90.930
# 10193       0.2  -0.6048         3    3.024
#
# [10194 rows x 4 columns]

# %%
Store_num.columns[2]
# Out:
# 'Quantity'

# %%
Store_num.Quantity<2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10189    False
# 10190    False
# 10191    False
# 10192    False
# 10193    False
# Name: Quantity, Length: 10194, dtype: bool

# %%
filter=Store_num.Quantity<2
filter
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10189    False
# 10190    False
# 10191    False
# 10192    False
# 10193    False
# Name: Quantity, Length: 10194, dtype: bool

# %%
Store_num[filter]
# Out:
#        Discount   Profit  Quantity    Sales
# 10          0.0   3.0084         1    6.540
# 18          0.0  21.2954         1   51.940
# 19          0.0   1.3583         1    2.890
# 53          0.7 -51.5154         1   67.194
# 57          0.0   4.0542         1   13.980
# ...         ...      ...       ...      ...
# 10166       0.0   1.9260         1    4.280
# 10167       0.2 -12.9568         1   64.784
# 10174       0.0  87.2842         1  300.980
# 10177       0.0  10.0282         1   34.580
# 10178       0.0   5.8891         1   12.530
#
# [933 rows x 4 columns]

# %%
Store_num[filter].head()
# Out:
#     Discount   Profit  Quantity   Sales
# 10       0.0   3.0084         1   6.540
# 18       0.0  21.2954         1  51.940
# 19       0.0   1.3583         1   2.890
# 53       0.7 -51.5154         1  67.194
# 57       0.0   4.0542         1  13.980

# %%
Store_num[filter][2:10]
# Out:
#     Discount   Profit  Quantity    Sales
# 19       0.0   1.3583         1    2.890
# 53       0.7 -51.5154         1   67.194
# 57       0.0   4.0542         1   13.980
# 62       0.0   3.7900         1    9.480
# 64       0.0   3.1100         1    6.480
# 79       0.0  14.3075         1   57.230
# 80       0.2   1.3257         1    3.928
# 96       0.0  42.0186         1  161.610

# %%
filter1=Store_num.Sales>10
filter1
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 10189     True
# 10190     True
# 10191    False
# 10192     True
# 10193    False
# Name: Sales, Length: 10194, dtype: bool

# %%
Store_num[filter1]
# Out:
#        Discount    Profit  Quantity     Sales
# 0           0.2    5.5512         2    16.448
# 2           0.2    4.2717         3    11.784
# 3           0.2  -64.7748         3   272.736
# 4           0.2    4.8840         3    19.536
# 5           0.0  746.4078         9  2573.820
# ...         ...       ...       ...       ...
# 10187       0.0   56.5110         2   209.300
# 10188       0.2    4.5188         2    13.904
# 10189       0.2   19.7910         3    52.776
# 10190       0.2    6.4750         2    20.720
# 10192       0.0    2.7279         7    90.930
#
# [8796 rows x 4 columns]

# %%
filter&filter1
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10189    False
# 10190    False
# 10191    False
# 10192    False
# 10193    False
# Length: 10194, dtype: bool

# %%
Store_num[filter&filter1]
# Out:
#        Discount   Profit  Quantity    Sales
# 18          0.0  21.2954         1   51.940
# 53          0.7 -51.5154         1   67.194
# 57          0.0   4.0542         1   13.980
# 79          0.0  14.3075         1   57.230
# 96          0.0  42.0186         1  161.610
# ...         ...      ...       ...      ...
# 10129       0.7 -10.4184         1   13.023
# 10167       0.2 -12.9568         1   64.784
# 10174       0.0  87.2842         1  300.980
# 10177       0.0  10.0282         1   34.580
# 10178       0.0   5.8891         1   12.530
#
# [564 rows x 4 columns]

# %%
Store_num[(Store_num.Quantity>5) &(Store_num.Sales>30)]
# Out:
#        Discount    Profit  Quantity     Sales
# 5           0.0  746.4078         9  2573.820
# 22          0.0   87.3504         6   545.940
# 28          0.2   13.0928         7    37.408
# 29          0.0   34.3548         6   572.580
# 31          0.0  258.6960         6   646.740
# ...         ...       ...       ...       ...
# 10165       0.0   34.7760         7    72.450
# 10172       0.0  314.0384         8  1207.840
# 10175       0.0   37.4144         8   101.120
# 10183       0.0   35.4144         8    99.120
# 10192       0.0    2.7279         7    90.930
#
# [1569 rows x 4 columns]

# %%
Store_num[(Store_num.Quantity>5) &(Store_num.Sales>30) &(Store_num.Profit>50)]
# Out:
#        Discount     Profit  Quantity     Sales
# 5           0.0   746.4078         9  2573.820
# 22          0.0    87.3504         6   545.940
# 31          0.0   258.6960         6   646.740
# 59          0.0   181.9818         7   699.930
# 65          0.0    58.6600        10   209.500
# ...         ...        ...       ...       ...
# 10066       0.0   412.5394         7  1586.690
# 10091       0.4    94.4937         7   629.958
# 10121       0.2  1007.9832         6  2879.952
# 10137       0.0   301.9680         6   629.100
# 10172       0.0   314.0384         8  1207.840
#
# [574 rows x 4 columns]

# %%
len(Store_num[(Store_num.Quantity>5) &(Store_num.Sales>30) &(Store_num.Profit>50)])
# Out:
# 574

# %%
Store_num[(Store_num.Quantity>5) &(Store_num.Sales>30) &(Store_num.Profit>50)].head()
# Out:
#     Discount    Profit  Quantity    Sales
# 5        0.0  746.4078         9  2573.82
# 22       0.0   87.3504         6   545.94
# 31       0.0  258.6960         6   646.74
# 59       0.0  181.9818         7   699.93
# 65       0.0   58.6600        10   209.50

# %%
Store_num[(Store_num.Quantity>5) &(Store_num.Sales>30) &(Store_num.Profit>50)].tail()
# Out:
#        Discount     Profit  Quantity     Sales
# 10066       0.0   412.5394         7  1586.690
# 10091       0.4    94.4937         7   629.958
# 10121       0.2  1007.9832         6  2879.952
# 10137       0.0   301.9680         6   629.100
# 10172       0.0   314.0384         8  1207.840

# %%
Store_num.Sales==60
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10189    False
# 10190    False
# 10191    False
# 10192    False
# 10193    False
# Name: Sales, Length: 10194, dtype: bool

# %%
Store_num[Store_num.Sales!=60]
# Out:
#        Discount   Profit  Quantity    Sales
# 0           0.2   5.5512         2   16.448
# 1           0.8  -5.4870         2    3.540
# 2           0.2   4.2717         3   11.784
# 3           0.2 -64.7748         3  272.736
# 4           0.2   4.8840         3   19.536
# ...         ...      ...       ...      ...
# 10189       0.2  19.7910         3   52.776
# 10190       0.2   6.4750         2   20.720
# 10191       0.2  -0.6048         3    3.024
# 10192       0.0   2.7279         7   90.930
# 10193       0.2  -0.6048         3    3.024
#
# [10194 rows x 4 columns]

# %%
Store_num[Store_num.Sales>60]
# Out:
#        Discount    Profit  Quantity     Sales
# 3           0.2  -64.7748         3   272.736
# 5           0.0  746.4078         9  2573.820
# 8           0.0  274.4910         2   609.980
# 12          0.0  204.1092         4   755.960
# 13          0.0  113.6742         2   391.980
# ...         ...       ...       ...       ...
# 10183       0.0   35.4144         8    99.120
# 10184       0.0   20.5380         2    68.460
# 10186       0.2   12.1176         4   323.136
# 10187       0.0   56.5110         2   209.300
# 10192       0.0    2.7279         7    90.930
#
# [4879 rows x 4 columns]

# %%
len(Store_num[Store_num.Sales>60])
# Out:
# 4879

# %%
Store_num[Store_num.Sales>60][0:10]
# Out:
#     Discount    Profit  Quantity     Sales
# 3       0.20  -64.7748         3   272.736
# 5       0.00  746.4078         9  2573.820
# 8       0.00  274.4910         2   609.980
# 12      0.00  204.1092         4   755.960
# 13      0.00  113.6742         2   391.980
# 14      0.60  -53.7096         3    76.728
# 21      0.15    3.9294         3   333.999
# 22      0.00   87.3504         6   545.940
# 29      0.00   34.3548         6   572.580
# 30      0.00  238.6530         5  1325.850

# %%
Store_num
# Out:
#        Discount   Profit  Quantity    Sales
# 0           0.2   5.5512         2   16.448
# 1           0.8  -5.4870         2    3.540
# 2           0.2   4.2717         3   11.784
# 3           0.2 -64.7748         3  272.736
# 4           0.2   4.8840         3   19.536
# ...         ...      ...       ...      ...
# 10189       0.2  19.7910         3   52.776
# 10190       0.2   6.4750         2   20.720
# 10191       0.2  -0.6048         3    3.024
# 10192       0.0   2.7279         7   90.930
# 10193       0.2  -0.6048         3    3.024
#
# [10194 rows x 4 columns]

# %%
Store_num[Store_num.Profit<90]
# Out:
#        Discount   Profit  Quantity    Sales
# 0           0.2   5.5512         2   16.448
# 1           0.8  -5.4870         2    3.540
# 2           0.2   4.2717         3   11.784
# 3           0.2 -64.7748         3  272.736
# 4           0.2   4.8840         3   19.536
# ...         ...      ...       ...      ...
# 10189       0.2  19.7910         3   52.776
# 10190       0.2   6.4750         2   20.720
# 10191       0.2  -0.6048         3    3.024
# 10192       0.0   2.7279         7   90.930
# 10193       0.2  -0.6048         3    3.024
#
# [9193 rows x 4 columns]

# %%
len(Store_num[Store_num.Profit<90])
# Out:
# 9193

# %%
len(Store_num.columns)
# Out:
# 4

# %%
Store_num[Store_num.Quantity==2]
# Out:
#        Discount    Profit  Quantity    Sales
# 0           0.2    5.5512         2   16.448
# 1           0.8   -5.4870         2    3.540
# 6           0.0    1.4796         2    5.480
# 8           0.0  274.4910         2  609.980
# 13          0.0  113.6742         2  391.980
# ...         ...       ...       ...      ...
# 10181       0.0  100.6560         2  209.700
# 10184       0.0   20.5380         2   68.460
# 10187       0.0   56.5110         2  209.300
# 10188       0.2    4.5188         2   13.904
# 10190       0.2    6.4750         2   20.720
#
# [2440 rows x 4 columns]

# %%
len(Store_num[Store_num.Quantity==3])
# Out:
# 2435

# %%
Store_num.Quantity.unique()
# Out:
# array([ 2,  3,  9,  4,  1,  7,  6,  5, 10,  8, 13, 14, 12, 11])

# %%
Store_num[Store_num.Quantity==12]
# Out:
#       Discount    Profit  Quantity     Sales
# 190        0.0    6.6240        12    82.800
# 367        0.4    8.3916        12    71.928
# 542        0.2  125.2692        12  1113.504
# 1444       0.2   15.5376        12    47.808
# 1849       0.2  135.4068        12  3610.848
# 3002       0.0   10.0128        12    35.760
# 3353       0.0  561.5640        12  1871.880
# 3841       0.2   42.5880        12   681.408
# 4171       0.0  167.8080        12   364.800
# 4926       0.2   18.7224        12    51.648
# 5343       0.0   23.4192        12   167.280
# 5915       0.0    0.9336        12    93.360
# 6096       0.2   15.7992        12    43.584
# 6308       0.2   21.8880        12    58.368
# 6319       0.0   11.3100        12    39.000
# 6594       0.0   36.9288        12    80.280
# 7682       0.2   42.5880        12   681.408
# 7986       0.0    1.6752        12    83.760
# 9067       0.0  130.7520        12   435.840
# 9285       0.2   20.9148        12  1673.184
# ...

# %%
Store_num.Profit/Store_num.Sales
# Out:
# 0        0.3375
# 1       -1.5500
# 2        0.3625
# 3       -0.2375
# 4        0.2500
#           ...
# 10189    0.3750
# 10190    0.3125
# 10191   -0.2000
# 10192    0.0300
# 10193   -0.2000
# Length: 10194, dtype: float64

# %%
Store_num['P/S']=Store_num.Profit/Store_num.Sales
Store_num
# Out:
#        Discount   Profit  Quantity    Sales     P/S
# 0           0.2   5.5512         2   16.448  0.3375
# 1           0.8  -5.4870         2    3.540 -1.5500
# 2           0.2   4.2717         3   11.784  0.3625
# 3           0.2 -64.7748         3  272.736 -0.2375
# 4           0.2   4.8840         3   19.536  0.2500
# ...         ...      ...       ...      ...     ...
# 10189       0.2  19.7910         3   52.776  0.3750
# 10190       0.2   6.4750         2   20.720  0.3125
# 10191       0.2  -0.6048         3    3.024 -0.2000
# 10192       0.0   2.7279         7   90.930  0.0300
# 10193       0.2  -0.6048         3    3.024 -0.2000
#
# [10194 rows x 5 columns]

# %%
Store_num['P/S']
# Out:
# 0        0.3375
# 1       -1.5500
# 2        0.3625
# 3       -0.2375
# 4        0.2500
#           ...
# 10189    0.3750
# 10190    0.3125
# 10191   -0.2000
# 10192    0.0300
# 10193   -0.2000
# Name: P/S, Length: 10194, dtype: float64

# %%
Store_num[['Profit','Sales','P/S']]
# Out:
#         Profit    Sales     P/S
# 0       5.5512   16.448  0.3375
# 1      -5.4870    3.540 -1.5500
# 2       4.2717   11.784  0.3625
# 3     -64.7748  272.736 -0.2375
# 4       4.8840   19.536  0.2500
# ...        ...      ...     ...
# 10189  19.7910   52.776  0.3750
# 10190   6.4750   20.720  0.3125
# 10191  -0.6048    3.024 -0.2000
# 10192   2.7279   90.930  0.0300
# 10193  -0.6048    3.024 -0.2000
#
# [10194 rows x 3 columns]
